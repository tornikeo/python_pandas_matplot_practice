# %% [markdown]
# <a href="https://colab.research.google.com/github/JoshK68/python_pandas_matplot_practice/blob/main/Python_and_Pandas_Review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def isMonotonic(array):

  #start with edgecases
  if len(array) <= 2:   #if array of size 1 or 2 then we know it's monotonic
    return True

  #then we set the direction to be the direction of the first 2 numbers

  direction = array[1] - array[0]
  for i in range(2, len(array)):  #we want to start at the 3rd number (we compared the first two numbers to determine the direction)
      if direction == 0:   #the direction could be flat (unmeaningful) for example if our array is [1, 1, 1, 3]
          direction = array[i] - array[i-1]
          continue

          if breaksDirection(direction, array[i-1], array[i]):
            return False
  return True

def breaksDirection(direction, previousInt, currentInt):

  difference = currentInt - previousInt #if our difference is equal to 0 then that just means that previousInt and currentInt are equal to each other. That doesn't break the direction
  if direction > 0:  #if our difference is positive, then our difference respects our direction...we're still trending up
      return difference < 0  #if direction is greater than 0 and difference is <0...then we're breaking our direction
  return difference > 0  #this line breaks the direction if the direction is positive

# %%
print(isMonotonic([2, 4, 10, 39, 42, 49]))
# Out:
# True

# %%
#Python challenges - Breadth-first Search (more difficult than depth first search)
#Out parent node will have children nodes.
#some of these children nodes will have other children nodes
#GOAL - traverse the tree level by level
#traverse each level entirely before moving on  - all all the nodes (letters) to an array

###Depth first search is different - in depth first search you traverse branch by branch


#Breadth first - go to child node then through all it's siblings
#for this we will use a Queue - first-in first out

# %%
#### ####
#class Node:

#  def _init_(self, name):
#    self.children = []
#    self.name = name

#  def addChild(self,name):
#    self.children.append(Node(name))

#  def breadthFirstSearch(self,array):
#    queue = [self]   #initiaze it on the first node that we're calling breadth first search on
#    while len(queue) > 0:   ##while the queue is not empty
#      current = queue.pop(0)
#      array.append(current.name)
#      for child in current.children:
#        queue.append(child)
#    return array

# %%
#print(breadthFirstSearch(A, B, C))

# %%
import pandas as pd

# %%
houses = pd.read_csv('/content/drive/MyDrive/Datasets/Independent_projects/DataAnalysisCourseMaterials.zip (Unzipped Files)/DataAnalysis/data/kc_house_data.csv')
houses
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 0      7129300520  20141013T000000  ...           1340        5650
# 1      6414100192  20141209T000000  ...           1690        7639
# 2      5631500400  20150225T000000  ...           2720        8062
# 3      2487200875  20141209T000000  ...           1360        5000
# 4      1954400510  20150218T000000  ...           1800        7503
# ...           ...              ...  ...            ...         ...
# 21608   263000018  20140521T000000  ...           1530        1509
# 21609  6600060120  20150223T000000  ...           1830        7200
# 21610  1523300141  20140623T000000  ...           1020        2007
# 21611   291310100  20150116T000000  ...           1410        1287
# 21612  1523300157  20141015T000000  ...           1020        1357
#
# [21613 rows x 21 columns]

# %%
first_5 = houses.head()
first_5
type(first_5)
# Out:
# pandas.core.frame.DataFrame

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
houses.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
titanic = pd.read_csv('/content/drive/MyDrive/Datasets/Independent_projects/DataAnalysisCourseMaterials.zip (Unzipped Files)/DataAnalysis/data/titanic.csv')
titanic.tail()
# Out:
#       pclass  survived                       name  ... boat body  home.dest
# 1304       3         0       Zabour, Miss. Hileni  ...    ?  328          ?
# 1305       3         0      Zabour, Miss. Thamine  ...    ?    ?          ?
# 1306       3         0  Zakarian, Mr. Mapriededer  ...    ?  304          ?
# 1307       3         0        Zakarian, Mr. Ortin  ...    ?    ?          ?
# 1308       3         0         Zimmerman, Mr. Leo  ...    ?    ?          ?
#
# [5 rows x 14 columns]

# %%
netflix = pd.read_csv('/content/drive/MyDrive/Datasets/Independent_projects/DataAnalysisCourseMaterials.zip (Unzipped Files)/DataAnalysis/data/netflix_titles.csv', sep='|', index_col=0)
#already has an index column in the csv file. Pandas, by default creates its own index. Or you could make the index column the title with: index_col=3. In this example index_col=0
netflix.head()
# Out:
#   show_id  ...                                        description
# 0      s1  ...  As her father nears the end of his life, filmm...
# 1      s2  ...  After crossing paths at a party, a Cape Town t...
# 2      s3  ...  To protect his family from a powerful drug lor...
# 3      s4  ...  Feuds, flirtations and toilet talk go down amo...
# 4      s5  ...  In a city of coaching centers known to train I...
#
# [5 rows x 12 columns]

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 894.5+ KB

# %%
###SUMLEV	REGION	DIVISION	STATE	NAME	CENSUS2010POP	ESTIMATESBASE2010	POPESTIMATE2010	POPESTIMATE2011	POPESTIMATE2012	POPESTIMATE2013	POPESTIMATE2014	POPESTIMATE2015	POPESTIMATE2016	POPESTIMATE2017	POPESTIMATE2018	POPESTIMATE2019	POPESTIMATE042020	POPESTIMATE2020
names = ['sumlev', 'region', 'division', 'state', 'name', 'census2010pop', 'estimatebase2010', 'popestimate2010', 'popestimate2011', 'popestimate2012', 'popestimate2013', 'popestimate2014', 'popestimate2015', 'popestimate2016', 'popestimate2017', 'popestimate2018', 'popestimate2019', 'popestimate042020', 'popestimate2020']

nst = pd.read_csv('/content/drive/MyDrive/Datasets/Independent_projects/DataAnalysisCourseMaterials.zip (Unzipped Files)/DataAnalysis/data/nst-est2020.csv', names=names)  #header = 0 tells it to ignore the header b/c we're providing our own with names
nst.head()
# Out:
#    sumlev  region  ...  popestimate042020  popestimate2020
# 0  SUMLEV  REGION  ...  POPESTIMATE042020  POPESTIMATE2020
# 1     010       0  ...          329398742        329484123
# 2     020       1  ...           55924275         55849869
# 3     020       2  ...           68357895         68316744
# 4     020       3  ...          126494232        126662754
#
# [5 rows x 19 columns]

# %%
bestsellers = pd.read_csv('/content/drive/MyDrive/Datasets/Independent_projects/DataAnalysisCourseMaterials.zip (Unzipped Files)/DataAnalysis/data/bestsellers.csv')

# %%
bestsellers.head(6)
#bestsellers.tail(5)
# Out:
#                                                 Name  ...        Genre
# 0                      10-Day Green Smoothie Cleanse  ...  Non Fiction
# 1                                  11/22/63: A Novel  ...      Fiction
# 2            12 Rules for Life: An Antidote to Chaos  ...  Non Fiction
# 3                             1984 (Signet Classics)  ...      Fiction
# 4  5,000 Awesome Facts (About Everything!) (Natio...  ...  Non Fiction
# 5      A Dance with Dragons (A Song of Ice and Fire)  ...      Fiction
#
# [6 rows x 7 columns]

# %%
bestsellers.info()   #550 entries. None are missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
bestsellers['User Rating'].dtype
# Out:
# dtype('float64')

# %%
mount_everest = pd.read_csv('/content/drive/MyDrive/Datasets/Independent_projects/DataAnalysisCourseMaterials.zip (Unzipped Files)/DataAnalysis/data/mount_everest_deaths.csv', index_col=0)

mount_everest.head()
# Out:
#        Name          Date  Age  ... Nationality Cause of death         Location
# No.                             ...
# 1     Dorje  June 7, 1922  NaN  ...       Nepal      Avalanche  Below North Col
# 2    Lhakpa  June 7, 1922  NaN  ...       Nepal      Avalanche  Below North Col
# 3     Norbu  June 7, 1922  NaN  ...       Nepal      Avalanche  Below North Col
# 4    Pasang  June 7, 1922  NaN  ...       Nepal      Avalanche  Below North Col
# 5      Pema  June 7, 1922  NaN  ...       Nepal      Avalanche  Below North Col
#
# [5 rows x 7 columns]

# %%
mount_everest.info()
#Age has the most null values
#Name and Date have no null-values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 310 entries, 1 to 310
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            310 non-null    object
#  1   Date            310 non-null    object
#  2   Age             160 non-null    float64
#  3   Expedition      271 non-null    object
#  4   Nationality     309 non-null    object
#  5   Cause of death  296 non-null    object
#  6   Location        291 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 19.4+ KB

# %%
names = ['id', 'title', 'year', 'imdb_rating', 'imdb_id', 'genres']

movie_titles = pd.read_csv('/content/drive/MyDrive/Datasets/Independent_projects/DataAnalysisCourseMaterials.zip (Unzipped Files)/DataAnalysis/data/movie_titles.tsv', sep='\t', names=names)
movie_titles.tail(7)
# Out:
#        id  ...                                             genres
# 610  m610  ...         ['adventure' 'family' 'fantasy' 'musical']
# 611  m611  ...                  ['action' 'adventure' 'thriller']
# 612  m612  ...  ['action' 'crime' 'fantasy' 'mystery' 'sci-fi'...
# 613  m613  ...                     ['action' 'adventure' 'crime']
# 614  m614  ...                                ['action' 'sci-fi']
# 615  m615  ...                                ['comedy' 'sci-fi']
# 616  m616  ...     ['action' 'adventure' 'drama' 'history' 'war']
#
# [7 rows x 6 columns]

# %%
houses.head(3)
# Out:
#            id             date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  20141013T000000  221900.0  ... -122.257           1340        5650
# 1  6414100192  20141209T000000  538000.0  ... -122.319           1690        7639
# 2  5631500400  20150225T000000  180000.0  ... -122.233           2720        8062
#
# [3 rows x 21 columns]

# %%
houses['price'].min()
# Out:
# 75000.0

# %%
houses.sum(numeric_only=True)   #so that we don't sum objects...
# Out:
# id               9.899406e+13
# price            1.167293e+10
# bedrooms         7.285400e+04
# bathrooms        4.570625e+04
# sqft_living      4.495287e+07
# sqft_lot         3.265069e+08
# floors           3.229650e+04
# waterfront       1.630000e+02
# view             5.064000e+03
# condition        7.368800e+04
# grade            1.654880e+05
# sqft_above       3.865249e+07
# sqft_basement    6.300385e+06
# yr_built         4.259933e+07
# yr_renovated     1.824186e+06
# zipcode          2.119759e+09
# lat              1.027915e+06
# long            -2.641409e+06
# sqft_living15    4.293536e+07
# sqft_lot15       2.759646e+08
# dtype: float64

# %%
titanic['survived'].sum()   #Tells us that 500 people survived (b/c it assigned 0=died and 1=survived)
# Out:
# 500

# %%
titanic.shape  #1309 people. 500 survived
# Out:
# (1309, 14)

# %%
titanic.sum(numeric_only=True)
# Out:
# pclass      3004
# survived     500
# sibsp        653
# parch        504
# dtype: int64

# %%
houses.price.mean()
# Out:
# 540088.1417665294

# %%
houses['price'].mean()   ####round to 2 decimal spaces
# Out:
# 540088.1417665294

# %%
titanic.describe().round(2)
# Out:
#         pclass  survived    sibsp    parch
# count  1309.00   1309.00  1309.00  1309.00
# mean      2.29      0.38     0.50     0.39
# std       0.84      0.49     1.04     0.87
# min       1.00      0.00     0.00     0.00
# 25%       2.00      0.00     0.00     0.00
# 50%       3.00      0.00     0.00     0.00
# 75%       3.00      1.00     1.00     0.00
# max       3.00      1.00     8.00     9.00

# %%
###lower std means that values are tighter together (closer to the average)
#higher std means values are more spread out or dispersed

# %%
houses.describe().round(2)
# Out:
#                  id       price  bedrooms  ...      long  sqft_living15  sqft_lot15
# count  2.161300e+04    21613.00  21613.00  ...  21613.00       21613.00    21613.00
# mean   4.580302e+09   540088.14      3.37  ...   -122.21        1986.55    12768.46
# std    2.876566e+09   367127.20      0.93  ...      0.14         685.39    27304.18
# min    1.000102e+06    75000.00      0.00  ...   -122.52         399.00      651.00
# 25%    2.123049e+09   321950.00      3.00  ...   -122.33        1490.00     5100.00
# 50%    3.904930e+09   450000.00      3.00  ...   -122.23        1840.00     7620.00
# 75%    7.308900e+09   645000.00      4.00  ...   -122.12        2360.00    10083.00
# max    9.900000e+09  7700000.00     33.00  ...   -121.32        6210.00   871200.00
#
# [8 rows x 20 columns]

# %%
# The 25th percentile is the value at which 25% of the answers lie below that value, and 75% of the answers lie above that value. 50th Percentile - Also known as the Median. ... 75th Percentile - Also known as the third, or upper, quartile.
# the 75 percentile is the value at which 75% below and only 25% above
### so 25th percentile and 75 percentile focus mean 25% below and 75% below ###

# %%
titanic.describe(include=['O'])   ### the default only includes the numeric columns
                                  ### you can do 'all' to include all
                                  ### or 'O' to include objects
# Out:
#                         name   sex   age  ...  boat  body home.dest
# count                   1309  1309  1309  ...  1309  1309      1309
# unique                  1307     2    99  ...    28   122       370
# top     Connolly, Miss. Kate  male     ?  ...     ?     ?         ?
# freq                       2   843   263  ...   823  1188       564
#
# [4 rows x 10 columns]

# %%
titanic.describe(include=['object'])  #we can write out the word object
                                      #we can also pass in a list of items to include
# Out:
#                         name   sex   age  ...  boat  body home.dest
# count                   1309  1309  1309  ...  1309  1309      1309
# unique                  1307     2    99  ...    28   122       370
# top     Connolly, Miss. Kate  male     ?  ...     ?     ?         ?
# freq                       2   843   263  ...   823  1188       564
#
# [4 rows x 10 columns]

# %%
titanic.head(2)
# Out:
#    pclass  survived  ... body                        home.dest
# 0       1         1  ...    ?                     St Louis, MO
# 1       1         1  ...    ?  Montreal, PQ / Chesterville, ON
#
# [2 rows x 14 columns]

# %%
#How can you work with just the name?
#dot notion vs ['']

titanic.name.head()
# Out:
# 0                      Allen, Miss. Elisabeth Walton
# 1                     Allison, Master. Hudson Trevor
# 2                       Allison, Miss. Helen Loraine
# 3               Allison, Mr. Hudson Joshua Creighton
# 4    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# Name: name, dtype: object

# %%
#dot notion doesn't work if there's a space, dot... etc in the name
#ex: titanic.home.dest - will give us an error
#but
#ex: titanic['home.dest'] works

# [' '] - square brackets also works well to select multiple columns

# %%
### square brackets can also be used effectively to get info out of a column

mystery_col = titanic['name']

# %%
### ###   #### ####
####titanic[mystery_col]

# %%
houses.price
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
#titanic.name - series = row + axis label (0, 1, 2)

# %%
#houses.sum()  - look at numeric only b/c we don't want to sum columns like date

# %%
houses.sum(numeric_only=True)
# Out:
# id               9.899406e+13
# price            1.167293e+10
# bedrooms         7.285400e+04
# bathrooms        4.570625e+04
# sqft_living      4.495287e+07
# sqft_lot         3.265069e+08
# floors           3.229650e+04
# waterfront       1.630000e+02
# view             5.064000e+03
# condition        7.368800e+04
# grade            1.654880e+05
# sqft_above       3.865249e+07
# sqft_basement    6.300385e+06
# yr_built         4.259933e+07
# yr_renovated     1.824186e+06
# zipcode          2.119759e+09
# lat              1.027915e+06
# long            -2.641409e+06
# sqft_living15    4.293536e+07
# sqft_lot15       2.759646e+08
# dtype: float64

# %%
houses['price'].sum()
# Out:
# 11672925008.0

# %%
mins = houses.min(numeric_only=True)

# %%
netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
netflix.release_year.describe()
# Out:
# count    8807.000000
# mean     2014.180198
# std         8.819312
# min      1925.000000
# 25%      2013.000000
# 50%      2017.000000
# 75%      2019.000000
# max      2021.000000
# Name: release_year, dtype: float64

# %%
titanic.pclass.nlargest(5)
# Out:
# 600    3
# 601    3
# 602    3
# 603    3
# 604    3
# Name: pclass, dtype: int64

# %%
houses.nlargest(5, ['price'] )
# Out:
#               id             date  ...  sqft_living15  sqft_lot15
# 7252  6762700020  20141013T000000  ...           3940        8800
# 3914  9808700762  20140611T000000  ...           3930       25449
# 9254  9208900037  20140919T000000  ...           4540       42730
# 4411  2470100110  20140804T000000  ...           3560       24345
# 1448  8907500070  20150413T000000  ...           4600       21750
#
# [5 rows x 21 columns]

# %%
houses.nlargest(5, ['bedrooms', 'bathrooms'])  ### sort by bedrooms and if there's a tie than sort by largest # of bathrooms
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 15870  2402100895  20140625T000000  ...           1330        4700
# 8757   1773100755  20140821T000000  ...           1420        4960
# 13314   627300145  20140814T000000  ...           2730       10400
# 19254  8812401450  20141229T000000  ...           1810        3745
# 15161  5566100170  20141029T000000  ...           2040       11914
#
# [5 rows x 21 columns]

# %%
##remember to pass in a list

select_multiple_cols = houses[['price', 'bedrooms']]
select_multiple_cols
# Out:
#           price  bedrooms
# 0      221900.0         3
# 1      538000.0         3
# 2      180000.0         2
# 3      604000.0         4
# 4      510000.0         3
# ...         ...       ...
# 21608  360000.0         3
# 21609  400000.0         4
# 21610  402101.0         2
# 21611  400000.0         3
# 21612  325000.0         2
#
# [21613 rows x 2 columns]

# %%
houses[['price', 'bedrooms', 'bathrooms']].describe() #getting stats for these three columns
# Out:
#               price      bedrooms     bathrooms
# count  2.161300e+04  21613.000000  21613.000000
# mean   5.400881e+05      3.370842      2.114757
# std    3.671272e+05      0.930062      0.770163
# min    7.500000e+04      0.000000      0.000000
# 25%    3.219500e+05      3.000000      1.750000
# 50%    4.500000e+05      3.000000      2.250000
# 75%    6.450000e+05      4.000000      2.500000
# max    7.700000e+06     33.000000      8.000000

# %%
###might be easier to read way to do it ###

house_size = ['bedrooms', 'bathrooms', 'sqft_living']
houses[house_size]  #still nested list
# Out:
#        bedrooms  bathrooms  sqft_living
# 0             3       1.00         1180
# 1             3       2.25         2570
# 2             2       1.00          770
# 3             4       3.00         1960
# 4             3       2.00         1680
# ...         ...        ...          ...
# 21608         3       2.50         1530
# 21609         4       2.50         2310
# 21610         2       0.75         1020
# 21611         3       2.50         1600
# 21612         2       0.75         1020
#
# [21613 rows x 3 columns]

# %%
houses.head(2)
# Out:
#            id             date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  20141013T000000  221900.0  ... -122.257           1340        5650
# 1  6414100192  20141209T000000  538000.0  ... -122.319           1690        7639
#
# [2 rows x 21 columns]

# %%
houses[['bedrooms', 'bathrooms']].value_counts()
# Out:
# bedrooms  bathrooms
# 4         2.50         2502
# 3         2.50         2357
#           1.75         1870
#           1.00         1780
# 2         1.00         1558
#                        ...
# 7         1.00            1
#           3.25            1
#           5.50            1
#           5.75            1
# 33        1.75            1
# Length: 144, dtype: int64

# %%
###Plotting with Pandas:
#by default it plots the values vs the labels#

# %%
houses.bedrooms.plot();   #so this is the default, and it's just plotting the number of bedrooms vs the labels which is the 'index'
                          #not very useful, in this case, to compare the #of bedrooms vs the index (house #1 vs house #20,000)
                          #A line plot is the default

# %%
houses.bedrooms.value_counts()#.plot()  ###then the value counts becomes the index
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
###let's plot that:

houses.bedrooms.value_counts().plot();

# %%
#This shows us that 2-4 bedrooms is much more common...let's change the kind to make it much more readable

houses.bedrooms.value_counts().plot(kind='bar');

# %%
titanic['survived']  #each passanger is either a 0 or 1

titanic['survived'].value_counts().plot(kind='pie');  ###very interesting!

# %%
###the above is for plotting in a Series

### In a dataframe you got to specify which data is for the X and which for the y!  ###

# %%
df = houses[['bedrooms', 'bathrooms']]
###
df.plot(x='bedrooms', y='bathrooms');

# %%
df.plot(x='bedrooms', y='bathrooms', kind='scatter');  #### ####  what to plot as x and y

# %%
netflix.rating.value_counts().head(8).plot(kind='bar');

# %%
bestsellers.Name
# Out:
# 0                          10-Day Green Smoothie Cleanse
# 1                                      11/22/63: A Novel
# 2                12 Rules for Life: An Antidote to Chaos
# 3                                 1984 (Signet Classics)
# 4      5,000 Awesome Facts (About Everything!) (Natio...
#                              ...
# 545         Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546    You Are a Badass: How to Stop Doubting Your Gr...
# 547    You Are a Badass: How to Stop Doubting Your Gr...
# 548    You Are a Badass: How to Stop Doubting Your Gr...
# 549    You Are a Badass: How to Stop Doubting Your Gr...
# Name: Name, Length: 550, dtype: object

# %%
bestsellers['User Rating']
# Out:
# 0      4.7
# 1      4.6
# 2      4.7
# 3      4.7
# 4      4.8
#       ...
# 545    4.9
# 546    4.7
# 547    4.7
# 548    4.7
# 549    4.7
# Name: User Rating, Length: 550, dtype: float64

# %%
bestsellers['Author'].head(8)
# Out:
# 0                    JJ Smith
# 1                Stephen King
# 2          Jordan B. Peterson
# 3               George Orwell
# 4    National Geographic Kids
# 5         George R. R. Martin
# 6         George R. R. Martin
# 7                 Amor Towles
# Name: Author, dtype: object

# %%
bestsellers['Author'].nunique()
# Out:
# 248

# %%
bestsellers['Price'].mean()
# Out:
# 13.1

# %%
bestsellers['Price'].nlargest(10)
# Out:
# 69     105
# 70     105
# 473     82
# 151     54
# 346     53
# 159     52
# 271     46
# 272     46
# 273     46
# 274     46
# Name: Price, dtype: int64

# %%
bestsellers.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
books_df = bestsellers[['Price', 'Name']].head(10)
books_df = books_df.sort_values(by=['Price'], ascending=False)

# %%
books_df.plot(x='Name', y='Price', kind='bar'); ####.sort_values();   ### Works great! Except why doesn't sort_columns work here???? - Fixed in previous line!!! ###

# %%
books_df.sort_values(by=['Price'], ascending=False)
# Out:
#    Price                                               Name
# 6     30  A Game of Thrones / A Clash of Kings / A Storm...
# 1     22                                  11/22/63: A Novel
# 2     15            12 Rules for Life: An Antidote to Chaos
# 7     15                     A Gentleman in Moscow: A Novel
# 4     12  5,000 Awesome Facts (About Everything!) (Natio...
# 5     11      A Dance with Dragons (A Song of Ice and Fire)
# 0      8                      10-Day Green Smoothie Cleanse
# 9      8                          A Man Called Ove: A Novel
# 3      6                             1984 (Signet Classics)
# 8      3      A Higher Loyalty: Truth, Lies, and Leadership

# %%
most_common_titles = bestsellers['Name'].sort_values(ascending=False).head(3)
most_common_titles
# Out:
# 549    You Are a Badass: How to Stop Doubting Your Gr...
# 548    You Are a Badass: How to Stop Doubting Your Gr...
# 547    You Are a Badass: How to Stop Doubting Your Gr...
# Name: Name, dtype: object

# %%
bestsellers['Genre'].value_counts().plot(kind='pie');

# %%
bestsellers['Author'].value_counts().head(10).plot(kind='barh');   ###barh easier to reach in this case - h == horizontal

# %%
###histograms automatically include the value counts...so no need to do .value_count()
###

bestsellers['User Rating'].plot(kind='hist');

# %%
### pandas uses 0, 1, 2 as the default index. You can change it to whatever makes the most sense, for example the date

btc = pd.read_csv('/content/drive/MyDrive/Datasets/Independent_projects/DataAnalysisCourseMaterials.zip (Unzipped Files)/DataAnalysis/data/coin_Bitcoin.csv')
btc.head()   #there's a lot of repetive info here such as Bitcoin, BTC (they're all BTC).
# Let's just focus on the name, date and high and low prices
# Out:
#    SNo     Name Symbol  ...       Close  Volume     Marketcap
# 0    1  Bitcoin    BTC  ...  144.539993     0.0  1.603769e+09
# 1    2  Bitcoin    BTC  ...  139.000000     0.0  1.542813e+09
# 2    3  Bitcoin    BTC  ...  116.989998     0.0  1.298955e+09
# 3    4  Bitcoin    BTC  ...  105.209999     0.0  1.168517e+09
# 4    5  Bitcoin    BTC  ...   97.750000     0.0  1.085995e+09
#
# [5 rows x 10 columns]

# %%
btc.index  #the automatic index is a range that starts at 0 and goes to 2991
# Out:
# RangeIndex(start=0, stop=2991, step=1)

# %%
###let's change the index from 0 - 2991 to the date

#btc.set_index('Date', inplace=True)  #now it's on a differnt level

# %%
btc
# Out:
#        SNo     Name Symbol  ...         Close        Volume     Marketcap
# 0        1  Bitcoin    BTC  ...    144.539993  0.000000e+00  1.603769e+09
# 1        2  Bitcoin    BTC  ...    139.000000  0.000000e+00  1.542813e+09
# 2        3  Bitcoin    BTC  ...    116.989998  0.000000e+00  1.298955e+09
# 3        4  Bitcoin    BTC  ...    105.209999  0.000000e+00  1.168517e+09
# 4        5  Bitcoin    BTC  ...     97.750000  0.000000e+00  1.085995e+09
# ...    ...      ...    ...  ...           ...           ...           ...
# 2986  2987  Bitcoin    BTC  ...  33897.048590  3.872897e+10  6.354508e+11
# 2987  2988  Bitcoin    BTC  ...  34668.548402  2.438396e+10  6.499397e+11
# 2988  2989  Bitcoin    BTC  ...  35287.779766  2.492431e+10  6.615748e+11
# 2989  2990  Bitcoin    BTC  ...  33746.002456  2.672155e+10  6.326962e+11
# 2990  2991  Bitcoin    BTC  ...  34235.193451  2.650126e+10  6.418992e+11
#
# [2991 rows x 10 columns]

# %%
###Now when we look at individual data the index isn't the 0, 1,2, 3...
###it's the date which is much more insightful!

btc['High']
# Out:
# 0         147.488007
# 1         146.929993
# 2         139.889999
# 3         125.599998
# 4         108.127998
#             ...
# 2986    33939.588699
# 2987    34909.259899
# 2988    35937.567147
# 2989    35284.344430
# 2990    35038.536363
# Name: High, Length: 2991, dtype: float64

# %%
btc['High'].plot() #b/c we reset the index, now the Date show up on the bottom instead of the range of 0 to 2991
####How to include only some dates?

# %%
countries = pd.read_csv('/content/drive/MyDrive/Datasets/Independent_projects/DataAnalysisCourseMaterials.zip (Unzipped Files)/DataAnalysis/data/countries of the world.csv').head()
countries
# Out:
#            Country                               Region  ...  Industry  Service
# 0     Afghanistan         ASIA (EX. NEAR EAST)           ...      0,24     0,38
# 1         Albania   EASTERN EUROPE                       ...     0,188    0,579
# 2         Algeria   NORTHERN AFRICA                      ...       0,6    0,298
# 3  American Samoa   OCEANIA                              ...       NaN      NaN
# 4         Andorra   WESTERN EUROPE                       ...       NaN      NaN
#
# [5 rows x 20 columns]

# %%
###Taking a quick look at this df...likely we'd care about it being labeled by the country so let's set country as the index

countries.set_index('Country', inplace=True)
countries
# Out:
#                                               Region  ...  Service
# Country                                               ...
# Afghanistan            ASIA (EX. NEAR EAST)           ...     0,38
# Albania          EASTERN EUROPE                       ...    0,579
# Algeria          NORTHERN AFRICA                      ...    0,298
# American Samoa   OCEANIA                              ...      NaN
# Andorra          WESTERN EUROPE                       ...      NaN
#
# [5 rows x 19 columns]

# %%
###Notice how many spaces and funky characters there are in the column names such as: (per sq. mi.)
###if we were doing something serious with these, we're probably want to rename them to something simplier

# %%
countries['Population']
# Out:
# Country
# Afghanistan        31056997
# Albania             3581655
# Algeria            32930091
# American Samoa        57794
# Andorra               71201
# Name: Population, dtype: int64

# %%
###set index right in read_csv is the easiest way to do it
df = pd.read_csv('/content/drive/MyDrive/Datasets/Independent_projects/DataAnalysisCourseMaterials.zip (Unzipped Files)/DataAnalysis/data/world-happiness-report-2021.csv', index_col='Country name')
df.head(3)
# Out:
#              Regional indicator  ...  Dystopia + residual
# Country name                     ...
# Finland          Western Europe  ...                3.253
# Denmark          Western Europe  ...                2.868
# Switzerland      Western Europe  ...                2.839
#
# [3 rows x 19 columns]

# %%
df['Ladder score']   #the general world happiness report score
###b/c we set the countries to the index, now it makes more sense (it's no longer just 1, 2, 3...with the score)
# Out:
# Country name
# Finland        7.842
# Denmark        7.620
# Switzerland    7.571
# Iceland        7.554
# Netherlands    7.464
#                ...
# Lesotho        3.512
# Botswana       3.467
# Rwanda         3.415
# Zimbabwe       3.145
# Afghanistan    2.523
# Name: Ladder score, Length: 149, dtype: float64

# %%
df.sort_values('Healthy life expectancy').head(3)  #goes from lowest to highest by default
# Out:
#               Regional indicator  ...  Dystopia + residual
# Country name                      ...
# Chad          Sub-Saharan Africa  ...                3.209
# Lesotho       Sub-Saharan Africa  ...                1.800
# Nigeria       Sub-Saharan Africa  ...                2.736
#
# [3 rows x 19 columns]

# %%
df.sort_values('Healthy life expectancy', ascending=False)  #highest values = Singapore up top
###if you want to save then do inplace=True
# Out:
#                            Regional indicator  ...  Dystopia + residual
# Country name                                   ...
# Singapore                      Southeast Asia  ...                1.379
# Hong Kong S.A.R. of China           East Asia  ...                1.236
# Japan                               East Asia  ...                2.048
# Spain                          Western Europe  ...                2.513
# Switzerland                    Western Europe  ...                2.839
# ...                                       ...  ...                  ...
# Swaziland                  Sub-Saharan Africa  ...                2.155
# Ivory Coast                Sub-Saharan Africa  ...                3.469
# Nigeria                    Sub-Saharan Africa  ...                2.736
# Lesotho                    Sub-Saharan Africa  ...                1.800
# Chad                       Sub-Saharan Africa  ...                3.209
#
# [149 rows x 19 columns]

# %%
titanic.sort_values('name', key=lambda col: col.str.lower())  ###function takes a parameter (col) and runs str.lower() on that parameter ###
# Out:
#       pclass  survived  ... body               home.dest
# 600        3         0  ...    ?                       ?
# 601        3         0  ...    ?     East Providence, RI
# 602        3         0  ...  190     East Providence, RI
# 603        3         1  ...    ?     East Providence, RI
# 604        3         1  ...    ?  Norway Los Angeles, CA
# ...      ...       ...  ...  ...                     ...
# 1304       3         0  ...  328                       ?
# 1305       3         0  ...    ?                       ?
# 1306       3         0  ...  304                       ?
# 1307       3         0  ...    ?                       ?
# 1308       3         0  ...    ?                       ?
#
# [1309 rows x 14 columns]

# %%
#countries.sort_index()  #to sort the index alphabetically

# %%
houses.bedrooms.value_counts().sort_index().plot(kind='bar')

# %%
### .loc helps us view something by row vs by column

df.head(2)
###countries['Albania']   this doesn't work for a row, only for columns
df.loc["Canada"]  ### You get all the info for that one row
# Out:
# Regional indicator                            North America and ANZ
# Ladder score                                                  7.103
# Standard error of ladder score                                0.042
# upperwhisker                                                  7.185
# lowerwhisker                                                  7.021
# Logged GDP per capita                                        10.776
# Social support                                                0.926
# Healthy life expectancy                                        73.8
# Freedom to make life choices                                  0.915
# Generosity                                                    0.089
# Perceptions of corruption                                     0.415
# Ladder score in Dystopia                                       2.43
# Explained by: Log GDP per capita                              1.447
# Explained by: Social support                                  1.044
# ...

# %%
#You can also request it in dataframe structure
df.loc[["Canada"]]
# Out:
#                  Regional indicator  ...  Dystopia + residual
# Country name                         ...
# Canada        North America and ANZ  ...                2.585
#
# [1 rows x 19 columns]

# %%
###You can also get a list of countries (the from the ROWS) with .loc, say we want all the North American countries
###

df.loc[['Canada', 'Mexico', 'United States']]
# Out:
#                         Regional indicator  ...  Dystopia + residual
# Country name                                ...
# Canada               North America and ANZ  ...                2.585
# Mexico         Latin America and Caribbean  ...                2.961
# United States        North America and ANZ  ...                2.807
#
# [3 rows x 19 columns]

# %%
###The Titanic df is indexed by number so you'd just pass in the row index 0, 1, 2...

titanic.head(2)
# Out:
#    pclass  survived  ... body                        home.dest
# 0       1         1  ...    ?                     St Louis, MO
# 1       1         1  ...    ?  Montreal, PQ / Chesterville, ON
#
# [2 rows x 14 columns]

# %%
titanic.loc[7]
# Out:
# pclass                            1
# survived                          0
# name         Andrews, Mr. Thomas Jr
# sex                            male
# age                              39
# sibsp                             0
# parch                             0
# ticket                       112050
# fare                              0
# cabin                           A36
# embarked                          S
# boat                              ?
# body                              ?
# home.dest               Belfast, NI
# Name: 7, dtype: object

# %%
#titanic.loc[[7, 9, 876]]
##You can also use slices

df.loc['Canada': 'Mexico': 2]

##This won't work if Mexico comes before Canada. Would give error
# Out:
#                                     Regional indicator  ...  Dystopia + residual
# Country name                                            ...
# Canada                           North America and ANZ  ...                2.585
# Costa Rica                 Latin America and Caribbean  ...                3.387
# Czech Republic              Central and Eastern Europe  ...                3.124
# Belgium                                 Western Europe  ...                2.862
# Bahrain                   Middle East and North Africa  ...                2.631
# Taiwan Province of China                     East Asia  ...                2.687
# Saudi Arabia              Middle East and North Africa  ...                2.668
# Italy                                   Western Europe  ...                2.794
# Guatemala                  Latin America and Caribbean  ...                3.375
# Singapore                               Southeast Asia  ...                1.379
# ...

# %%
df.head()
# Out:
#              Regional indicator  ...  Dystopia + residual
# Country name                     ...
# Finland          Western Europe  ...                3.253
# Denmark          Western Europe  ...                2.868
# Switzerland      Western Europe  ...                2.839
# Iceland          Western Europe  ...                2.967
# Netherlands      Western Europe  ...                2.798
#
# [5 rows x 19 columns]

# %%
###.iloc also gets the ROW. You just tell it the index location that you want

df.iloc[20]
# Out:
# Regional indicator                            Western Europe
# Ladder score                                            6.69
# Standard error of ladder score                         0.037
# upperwhisker                                           6.762
# lowerwhisker                                           6.618
# Logged GDP per capita                                 10.704
# Social support                                         0.942
# Healthy life expectancy                                 74.0
# Freedom to make life choices                           0.822
# Generosity                                            -0.147
# Perceptions of corruption                              0.571
# Ladder score in Dystopia                                2.43
# Explained by: Log GDP per capita                       1.421
# Explained by: Social support                           1.081
# Explained by: Healthy life expectancy                  0.804
# ...

# %%
df.iloc[[20]]   ##double brackets to turn it into a df
# Out:
#              Regional indicator  ...  Dystopia + residual
# Country name                     ...
# France           Western Europe  ...                2.521
#
# [1 rows x 19 columns]

# %%
#You can still use a slice

df.iloc[20:23]
# Out:
#                         Regional indicator  ...  Dystopia + residual
# Country name                                ...
# France                      Western Europe  ...                2.521
# Bahrain       Middle East and North Africa  ...                2.631
# Malta                       Western Europe  ...                2.268
#
# [3 rows x 19 columns]

# %%
###
houses.loc[21612:21618, ['price', 'bedrooms']]   ###After the column we specify which column of info we want for those ROWS
# Out:
#           price  bedrooms
# 21612  325000.0         2

# %%
titanic.loc[50:60:2, ['survived', 'sex']]   ###   ### ###
# Out:
#     survived     sex
# 50         1  female
# 52         0    male
# 54         1    male
# 56         1    male
# 58         0    male
# 60         0    male

# %%
df.loc['Canada': 'France', ['Ladder score']]
# Out:
#                 Ladder score
# Country name
# Canada                 7.103
# Ireland                7.085
# Costa Rica             7.069
# United Kingdom         7.064
# Czech Republic         6.965
# United States          6.951
# Belgium                6.834
# France                 6.690

# %%
df.loc['Canada':'France'][['Ladder score']]  #You can also do it this way
###request the rows first (Canada to France) and then do a lookup/narrow down after the fact ###
# Out:
#                 Ladder score
# Country name
# Canada                 7.103
# Ireland                7.085
# Costa Rica             7.069
# United Kingdom         7.064
# Czech Republic         6.965
# United States          6.951
# Belgium                6.834
# France                 6.690

# %%
###How many people have exactly 33 bedrooms

houses['bedrooms'].value_counts().loc[33]  ### b/c value_counts makes the value the index!!!
# Out:
# 1

# %%
###titanic['age'].value_counts().loc[18] this gives us an casting error b/c even though...
###we'd think that age is an int, it's an object here b/c it has some '?' marks in it

# %%
#to get the value of it as an object you'd need to put it in quotes

titanic['age'].value_counts().loc['18']   ####  ####
# Out:
# 39

# %%
#titanic['age'].value_counts()

# %%
### https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html  ###
